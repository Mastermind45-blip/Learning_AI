# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = 'data/small-scale-cattle-diseases-infection-occurence.csv'
df = pd.read_csv(data)
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#     adm1cd            adm1nm Tick_Borne_Infected_ Tick_Borne_Treated  \
# 0   TZA001            Arusha              365,918            362,436
# 1   TZA002     Dar-es-salaam                  424                424
# 2   TZA003            Dodoma              274,264            261,482
# 3   TZA004             Geita              105,422            106,648
# 4   TZA005            Iringa               41,847             51,277
# 5   TZA006            Kagera              121,125            137,431
# 6   TZA007   Kaskazini Pemba                2,975              2,082
# 7   TZA008  Kaskazini Unguja                5,830              5,743
# 8   TZA009            Katavi               18,121             18,121
# 9   TZA010            Kigoma              105,671            105,671
# 10  TZA011       Kilimanjaro              219,654            211,214
# 11  TZA012      Kusini Pemba                6,895              8,216
# 12  TZA013     Kusini Unguja                6,829              6,829
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x='Tick_Borne_Infected_', data=df);

# %%
sns.displot(df.Tick_Borne_Infected_);
