# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print(pd.__version__)
# Out:
# 2.2.0

# %% [markdown]
# Sumber: https://www.kaggle.com/datasets/ashtired11/cattle-diseases

# %%
# data_sapi_yang_pernah_terinfeksi = 'vg_cattle.csv'
# df = pd.read_csv(data_sapi_yang_pernah_terinfeksi)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# df

# %%
print("Data statistik deskriptif sapi yang pernah terkena penyakit:")
df.describe()
# Out:
# Data statistik deskriptif sapi yang pernah terkena penyakit:
#         adm1cd  adm1nm Tick Borne Infected  Tick Borne Treated  \
# count       31      31                   31                 31
# unique      31      31                   31                 31
# top     TZA001  Arusha              365,918            362,436
# freq         1       1                    1                  1
#
#        Tick Borne Recovered Died of Tick Borne CBPP Infected  CBPP  Treated  \
# count                    31                 31             31            31
# unique                   31                 29             31            31
# top                 355,970                  0        315,681       300,427
# freq                      1                  3              1             1
#
#        CBPP  Recovered Died of CBPP   Trypanosomiasis Infected  \
# count               31             31                       31
# unique              30             30                       30
# ...

# %% [markdown]
# Sumber: https://data.apps.fao.org/catalog/dataset/small-scale-cattle-diseases-infection-occurrence-tanzania-adm1-2019-20-nbs/resource/57f02a52-f031-4aef-9062-2caa20ef6f5d

# %%
data_sapi_yang_pernah_terinfeksi_di_afrika = 'small-scale-cattle-diseases-infection-occurence.csv'
df = pd.read_csv(data_sapi_yang_pernah_terinfeksi_di_afrika)
df
# Out:
#     adm1cd            adm1nm Tick Borne Infected  Tick Borne Treated  \
# 0   TZA001            Arusha              365,918            362,436
# 1   TZA002     Dar-es-salaam                  424                424
# 2   TZA003            Dodoma              274,264            261,482
# 3   TZA004             Geita              105,422            106,648
# 4   TZA005            Iringa               41,847             51,277
# 5   TZA006            Kagera              121,125            137,431
# 6   TZA007   Kaskazini Pemba                2,975              2,082
# 7   TZA008  Kaskazini Unguja                5,830              5,743
# 8   TZA009            Katavi               18,121             18,121
# 9   TZA010            Kigoma              105,671            105,671
# 10  TZA011       Kilimanjaro              219,654            211,214
# 11  TZA012      Kusini Pemba                6,895              8,216
# 12  TZA013     Kusini Unguja                6,829              6,829
# ...
